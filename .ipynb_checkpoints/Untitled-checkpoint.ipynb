# %% [markdown]
# # EEG Time Series Classification
# ### Classify if eyes are open or shut with EEG Sensor Data

# %%
from scipy.io import arff
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from sklearn.model_selection import train_test_split

# %%
data = arff.loadarff('./Data/EEG Eye State.arff')
df = pd.DataFrame(data[0])

# %%
df.eyeDetection.unique()
# Out:
# array([b'0', b'1'], dtype=object)

# %%
df['eyeDetection'] = df['eyeDetection'].apply(lambda x: 0 if b'0' in x else 1)

# %%
sns.countplot(data=df, x='eyeDetection')
plt.show()

# %%
df
# Out:
#            AF3       F7       F3      FC5       T7       P7       O1       O2  \
# 0      4329.23  4009.23  4289.23  4148.21  4350.26  4586.15  4096.92  4641.03
# 1      4324.62  4004.62  4293.85  4148.72  4342.05  4586.67  4097.44  4638.97
# 2      4327.69  4006.67  4295.38  4156.41  4336.92  4583.59  4096.92  4630.26
# 3      4328.72  4011.79  4296.41  4155.90  4343.59  4582.56  4097.44  4630.77
# 4      4326.15  4011.79  4292.31  4151.28  4347.69  4586.67  4095.90  4627.69
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14975  4281.03  3990.26  4245.64  4116.92  4333.85  4614.36  4074.87  4625.64
# 14976  4276.92  3991.79  4245.13  4110.77  4332.82  4615.38  4073.33  4621.54
# 14977  4277.44  3990.77  4246.67  4113.85  4333.33  4615.38  4072.82  4623.59
# 14978  4284.62  3991.79  4251.28  4122.05  4334.36  4616.41  4080.51  4628.72
# 14979  4287.69  3997.44  4260.00  4121.03  4333.33  4616.41  4088.72  4638.46
#
#             P8       T8      FC6       F4       F8      AF4  eyeDetection
# 0      4222.05  4238.46  4211.28  4280.51  4635.90  4393.85             0
# 1      4210.77  4226.67  4207.69  4279.49  4632.82  4384.10             0
# 2      4207.69  4222.05  4206.67  4282.05  4628.72  4389.23             0
# 3      4217.44  4235.38  4210.77  4287.69  4632.31  4396.41             0
# 4      4210.77  4244.10  4212.82  4288.21  4632.82  4398.46             0
# ...        ...      ...      ...      ...      ...      ...           ...
# 14975  4203.08  4221.54  4171.28  4269.23  4593.33  4340.51             1
# 14976  4194.36  4217.44  4162.56  4259.49  4590.26  4333.33             1
# 14977  4193.33  4212.82  4160.51  4257.95  4591.79  4339.49             1
# 14978  4200.00  4220.00  4165.64  4267.18  4596.41  4350.77             1
# 14979  4212.31  4226.67  4167.69  4274.36  4597.95  4350.77             1
#
# [14980 rows x 15 columns]

# %%
def plot_all_signals(save=False):
    for col in df.columns:
        a = df[col].values
        plt.figure(figsize=(18,3))
        plt.plot(a)
        if save:
            plt.savefig('./Plots/' + col + '.png')
        plt.show()

# %%
plot_all_signals()

# %% [markdown]
# #### Looks like we have Outlier in the Data!
# Let´s remove them!

# %% [markdown]
# ## Remove Outlier
# We remove all outlier, that are 4 standard deviations under and above the mean!

# %%
def remove_outliers(dataframe, remove_above_std=4):
    '''Remove outlier that are 4 standard deviations away'''
    for col in dataframe.columns[:-1]:
        mean = np.mean(dataframe[col])
        std = np.std(dataframe[col])
        dataframe = dataframe[dataframe[col] > mean - remove_above_std*std]
        dataframe = dataframe[dataframe[col] < mean + remove_above_std*std]
    return dataframe
    
df = remove_outliers(df)

# %%
plot_all_signals(save=True)

# %% [markdown]
# Now the Data looks clean!
# We can go on the modeling part now.

# %% [markdown]
# ## Train Test Split & Scaling the data

# %%
y = df['eyeDetection'].values
y = tf.keras.utils.to_categorical(y)
X = df.drop('eyeDetection', axis=1).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Dense Neural Network

# %%
class DenseModel(tf.keras.Model):
    def __init__(self, n_inputs):
        super().__init__()
        
        self.fc1 = Dense(200, activation='relu', input_shape=(n_inputs,))
        self.fc2 = Dense(80, activation='relu')
        self.out = Dense(2, activation='softmax')
    
    def call(self, inputs):
        x = self.fc1(inputs)
        x = self.fc2(x)
        x = self.out(x)
        return x
    
model = DenseModel(n_inputs=X_train.shape[1])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train,
                    y_train,
                    shuffle=True,
                    epochs=40,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 300/300 [==============================] - 1s 5ms/step - loss: 0.4778 - accuracy: 0.7789 - val_loss: 0.3550 - val_accuracy: 0.8502
# Epoch 2/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.3035 - accuracy: 0.8768 - val_loss: 0.2810 - val_accuracy: 0.8782
# Epoch 3/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2469 - accuracy: 0.8990 - val_loss: 0.2610 - val_accuracy: 0.8988
# Epoch 4/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.2057 - accuracy: 0.9154 - val_loss: 0.2245 - val_accuracy: 0.9000
# Epoch 5/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1818 - accuracy: 0.9282 - val_loss: 0.1865 - val_accuracy: 0.9227
# Epoch 6/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1591 - accuracy: 0.9376 - val_loss: 0.1729 - val_accuracy: 0.9290
# Epoch 7/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1446 - accuracy: 0.9441 - val_loss: 0.1518 - val_accuracy: 0.9407
# Epoch 8/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1279 - accuracy: 0.9522 - val_loss: 0.1543 - val_accuracy: 0.9413
# Epoch 9/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1183 - accuracy: 0.9559 - val_loss: 0.1518 - val_accuracy: 0.9379
# Epoch 10/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.1063 - accuracy: 0.9603 - val_loss: 0.1453 - val_accuracy: 0.9407
# Epoch 11/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0951 - accuracy: 0.9655 - val_loss: 0.1347 - val_accuracy: 0.9439
# Epoch 12/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0866 - accuracy: 0.9690 - val_loss: 0.1154 - val_accuracy: 0.9562
# Epoch 13/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0815 - accuracy: 0.9698 - val_loss: 0.1265 - val_accuracy: 0.9498
# Epoch 14/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0786 - accuracy: 0.9735 - val_loss: 0.1193 - val_accuracy: 0.9513
# Epoch 15/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0724 - accuracy: 0.9750 - val_loss: 0.1312 - val_accuracy: 0.9515
# Epoch 16/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0732 - accuracy: 0.9726 - val_loss: 0.1069 - val_accuracy: 0.9568
# Epoch 17/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0629 - accuracy: 0.9799 - val_loss: 0.1126 - val_accuracy: 0.9583
# Epoch 18/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0594 - accuracy: 0.9799 - val_loss: 0.1413 - val_accuracy: 0.9466
# Epoch 19/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0581 - accuracy: 0.9800 - val_loss: 0.1283 - val_accuracy: 0.9549
# Epoch 20/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0552 - accuracy: 0.9809 - val_loss: 0.1178 - val_accuracy: 0.9598
# Epoch 21/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0554 - accuracy: 0.9810 - val_loss: 0.1688 - val_accuracy: 0.9405
# Epoch 22/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0543 - accuracy: 0.9810 - val_loss: 0.1144 - val_accuracy: 0.9572
# Epoch 23/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0408 - accuracy: 0.9875 - val_loss: 0.1010 - val_accuracy: 0.9623
# Epoch 24/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0420 - accuracy: 0.9863 - val_loss: 0.1023 - val_accuracy: 0.9623
# Epoch 25/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0416 - accuracy: 0.9866 - val_loss: 0.1212 - val_accuracy: 0.9564
# Epoch 26/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0478 - accuracy: 0.9846 - val_loss: 0.1272 - val_accuracy: 0.9564
# Epoch 27/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.1028 - val_accuracy: 0.9619
# Epoch 28/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.0969 - val_accuracy: 0.9667
# Epoch 29/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0341 - accuracy: 0.9884 - val_loss: 0.1005 - val_accuracy: 0.9621
# Epoch 30/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.0907 - val_accuracy: 0.9687
# Epoch 31/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.1107 - val_accuracy: 0.9640
# Epoch 32/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0392 - accuracy: 0.9861 - val_loss: 0.1328 - val_accuracy: 0.9555
# Epoch 33/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0343 - accuracy: 0.9886 - val_loss: 0.0995 - val_accuracy: 0.9670
# Epoch 34/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0273 - accuracy: 0.9919 - val_loss: 0.1062 - val_accuracy: 0.9657
# Epoch 35/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0294 - accuracy: 0.9906 - val_loss: 0.0977 - val_accuracy: 0.9693
# Epoch 36/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0277 - accuracy: 0.9914 - val_loss: 0.1435 - val_accuracy: 0.9549
# Epoch 37/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0998 - val_accuracy: 0.9661
# Epoch 38/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0173 - accuracy: 0.9960 - val_loss: 0.1212 - val_accuracy: 0.9576
# Epoch 39/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0248 - accuracy: 0.9920 - val_loss: 0.1135 - val_accuracy: 0.9636
# Epoch 40/40
# 300/300 [==============================] - 1s 3ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 0.1332 - val_accuracy: 0.9578

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.legend()
plt.savefig('./Plots/loss.png')
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.legend()
plt.savefig('./Plots/acc.png')
plt.show()

# %%
pred_test = model.predict(X_test)

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title=' Confusion matrix',
                          cmap=None,
                          normalize=True,
                          dataset='_'):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / np.sum(cm).astype('float')
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(dataset + title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.savefig('Plots/cm' + dataset + '.png')
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(np.argmax(y_test,axis=1), np.argmax(pred_test,axis=1), normalize=None)
plot_confusion_matrix(cm, ['open', 'closed'], normalize=False)

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import accuracy_score


print('Recall:', recall_score(np.argmax(y_test,axis=1), np.argmax(pred_test,axis=1)))
print('Precision:', precision_score(np.argmax(y_test,axis=1), np.argmax(pred_test,axis=1)))
print('Accuracy:', accuracy_score(np.argmax(y_test,axis=1), np.argmax(pred_test,axis=1)))
# Out:
# Recall: 0.9714013346043852
# Precision: 0.936150666054203
# Accuracy: 0.9578479135776319
